# %% [markdown]
# sms_spam_classifier

# %%
# !git clone https://github.com/JayashanManodya/sms_spam_classifier.git
# Out:
# fatal: destination path 'sms_spam_classifier' already exists and is not an empty directory.

# %%
import pandas as pd
import nltk

# %% [markdown]
# Read Dataset

# %%
df = pd.read_csv('/content/sms_spam_classifier/spam.csv')

# %%
df.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis=1,inplace=True)

# %%
df.rename(columns={'v1':'class','v2':'sms'},inplace=True)
df.sample(10)
# Out:
#      class                                                sms
# 5457   ham                        Arun can u transfr me d amt
# 3406   ham  Beautiful Truth against Gravity.. Read careful...
# 2734   ham   Can you do a mag meeting this avo at some point?
# 4656  spam  PRIVATE! Your 2003 Account Statement for shows...
# 2689   ham  Ya ok, vikky vl c witin  &lt;#&gt; mins and il...
# 1724   ham            There bold 2  &lt;#&gt; . Is that yours
# 3929   ham  I thk Ì_ gotta go home by urself. Cos i'll b g...
# 4335   ham  Fyi I'm taking a quick shower, be at epsilon i...
# 1363   ham  Yetunde, i'm sorry but moji and i seem too bus...
# 1842   ham                      \Are you comingdown later?\""

# %%
df.groupby('class').describe()
# Out:
#         sms
#       count unique                                                top freq
# class
# ham    4825   4516                             Sorry, I'll call later   30
# spam    747    653  Please call our customer service representativ...    4

# %%
df = df.drop_duplicates(keep='first')

# %%
df.groupby('class').describe()
# Out:
#         sms
#       count unique                                                top freq
# class
# ham    4516   4516                         Rofl. Its true to its name    1
# spam    653    653  This is the 2nd time we have tried 2 contact u...    1

# %% [markdown]
# Data Visualization

# %%
df["length"] = df["sms"].apply(len)

# %%
df.sample(5)
# Out:
#      class                                                sms  length
# 2489   ham  I have 2 docs appointments next week.:/ I'm ti...     121
# 3926   ham  Lol ... I really need to remember to eat when ...     126
# 2821  spam  ROMCAPspam Everyone around should be respondin...     152
# 2908  spam  URGENT! Your Mobile number has been awarded wi...     137
# 5444   ham  Good morning. At the repair shop--the ONLY rea...      70
