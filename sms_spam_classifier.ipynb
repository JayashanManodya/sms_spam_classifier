# %% [markdown]
# <a href="https://colab.research.google.com/github/JayashanManodya/sms_spam_classifier/blob/main/sms_spam_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# sms_spam_classifier

# %%
# !git clone https://github.com/JayashanManodya/sms_spam_classifier.git
# Out:
# fatal: destination path 'sms_spam_classifier' already exists and is not an empty directory.

# %%
import pandas as pd
import nltk

# %%
df = pd.read_csv('/content/sms_spam_classifier/spam.csv')

# %%
df.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis=1,inplace=True)

# %%
df.rename(columns={'v1':'class','v2':'message'},inplace=True)
df.sample(10)
# Out:
#      class                                            message
# 2625  spam  FREE RING TONE just text \POLYS\" to 87131. Th...
# 807    ham                  Boooo you always work. Just quit.
# 2700   ham  Feb  &lt;#&gt;  is \I LOVE U\" day. Send dis t...
# 634   spam  Dear Voucher Holder, 2 claim this weeks offer,...
# 883    ham                        Dude we should go sup again
# 589    ham                 I'm in a meeting, call me later at
# 2566   ham                     You in your room? I need a few
# 1293   ham   Happy birthday... May all ur dreams come true...
# 1305   ham  Designation is software developer and may be s...
# 4904  spam  Warner Village 83118 C Colin Farrell in SWAT t...

# %%
df.groupby('class').describe()
# Out:
#       message
#         count unique                                                top freq
# class
# ham      4825   4516                             Sorry, I'll call later   30
# spam      747    653  Please call our customer service representativ...    4

# %%
df = df.drop_duplicates(keep='first', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-81-3985031689.py in <cell line: 0>()
# ----> 1 df = df.drop_duplicates(keep='first', inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'drop_duplicates'

# %%
df.groupby('class').describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-80-2341362809.py in <cell line: 0>()
# ----> 1 df.groupby('class').describe()
#
# AttributeError: 'NoneType' object has no attribute 'groupby'
